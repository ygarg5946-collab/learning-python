# %% [markdown]
# ### OBJECT ORIENTED PROGRAMMING!!

# %%
#SEE we have studied about the class and objects in first class that is so simple just think it deeply
# and when i talk about the classblueprint
#car=CarBlueprint() here CarBlueprint is the class and the car is the object
# it is known as the pascal case to differentiate between the variable name and blueprint
#

# %%
import turtle
